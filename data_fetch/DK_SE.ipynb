# %% [markdown]
# ## Import

# %%
import pandas as pd
import numpy as np
import requests
from func import global_id, quarter_to_month, reindex, GT_dict

# %% [markdown]
# ## DK

# %% [markdown]
# #### Target data

# %%
df_dk_target = pd.read_csv(r'data/target/df_DK_target.csv', parse_dates = ['date'])

# %%
df_dk_target = df_dk_target.sort_values(by=['ID', 'date'])

# %%
df_dk_target.date.min()
# Out:
# Timestamp('2008-01-01 00:00:00')

# %% [markdown]
# Create target lag

# %%
df_dk_target['target_lag'] = df_dk_target.groupby('ID').target_actual.shift(1)

# %% [markdown]
# #### Job posts

# %%
df_dk_jobs = pd.read_csv(r'data/job_posts/df_DK_jobposts_quarterly_final.csv', parse_dates = ['date'])

# %%
df_dk_jobs[df_dk_jobs.date == '2019-01-01'].jobs.sum()
# Out:
# 72786

# %%
df_dk_jobs = df_dk_jobs.drop(['labour_force'], axis = 1)

# %% [markdown]
# Merge on labour force

# %%
df_dk_labour = pd.read_csv(r'data/job_posts/df_DK_labour_force.csv', parse_dates = ['date'])

# %%
df_dk_jobs = df_dk_jobs.merge(df_dk_labour, on = ['date', 'ID'])

# %%
df_dk_jobs['labour_force'] = df_dk_jobs.groupby('ID').labour_force.shift(1)

# %% [markdown]
# Create job rate

# %%
jobs_list = ['jobs', 'sector_information_technology', 'sector_engineering_technology','sector_management_staff', 'sector_trade_service',
       'sector_industry_craft', 'sector_sales_communication',
       'sector_teaching', 'sector_office_finance', 'sector_social_health',
       'sector_other']

# %%
for col in jobs_list:
    df_dk_jobs[col] = (df_dk_jobs[col] / df_dk_jobs['labour_force'])*100

# %%
df_dk_jobs = df_dk_jobs.drop(['labour_force'], axis = 1)

# %%
df_dk_jobs.date.min()
# Out:
# Timestamp('2008-01-01 00:00:00')

# %%
df_dk_jobs
# Out:
#           date      jobs             ID  sector_information_technology  \
# 0   2008-01-01       NaN        Capital                            NaN
# 1   2008-04-01  3.432511        Capital                       0.269507
# 2   2008-07-01  2.837729        Capital                       0.236353
# 3   2008-10-01  2.253597        Capital                       0.179017
# 4   2009-01-01  1.941019        Capital                       0.129733
# ..         ...       ...            ...                            ...
# 225 2018-04-01  2.171530  North Denmark                       0.102135
# 226 2018-07-01  1.797857  North Denmark                       0.089643
# 227 2018-10-01  1.690068  North Denmark                       0.084589
# 228 2019-01-01  1.880623  North Denmark                       0.095156
# 229 2019-04-01  1.988055  North Denmark                       0.084642
#
#      sector_engineering_technology  sector_management_staff  \
# 0                              NaN                      NaN
# 1                         0.229372                 0.342377
# 2                         0.195413                 0.294151
# 3                         0.171703                 0.253118
# 4                         0.139442                 0.204126
# ..                             ...                      ...
# 225                       0.167260                 0.222776
# 226                       0.135000                 0.195714
# 227                       0.152397                 0.202055
# 228                       0.143599                 0.194118
# 229                       0.145051                 0.191126
#
#      sector_trade_service  sector_industry_craft  sector_sales_communication  \
# 0                     NaN                    NaN                         NaN
# 1                0.502130               0.298991                    0.262332
# 2                0.424885               0.221101                    0.221674
# 3                0.277818               0.119424                    0.174460
# 4                0.239806               0.083374                    0.130947
# ..                    ...                    ...                         ...
# 225              0.317794               0.360498                    0.162633
# 226              0.273571               0.287857                    0.151071
# 227              0.193151               0.261644                    0.164384
# 228              0.264014               0.284775                    0.178547
# 229              0.293857               0.322526                    0.174744
#
#      sector_teaching  sector_office_finance  sector_social_health  \
# 0                NaN                    NaN                   NaN
# 1           0.404260               0.754933              0.402130
# 2           0.356995               0.601147              0.338188
# 3           0.297842               0.485731              0.330096
# 4           0.264078               0.399879              0.357403
# ..               ...                    ...                   ...
# 225         0.267260               0.260498              0.342705
# 226         0.206786               0.214643              0.305357
# 227         0.199658               0.224658              0.298288
# 228         0.169204               0.253979              0.349481
# 229         0.230717               0.232765              0.311263
#
#      sector_other
# 0             NaN
# 1        0.372197
# 2        0.288073
# 3        0.235612
# 4        0.228398
# ..            ...
# 225      0.366192
# 226      0.288571
# 227      0.270205
# 228      0.342561
# 229      0.373720
#
# [230 rows x 13 columns]

# %% [markdown]
# #### Google

# %% [markdown]
# #### Regional

# %%
df_dk_controls = pd.read_csv(r'data/other/df_controls.csv', parse_dates = ['date'])

# %%
df_dk_controls = df_dk_controls.drop(['w_ave_socio_index', 'avg_age'], axis = 1)

# %%
df_dk_controls = df_dk_controls[df_dk_controls['date'].map(lambda x: x.month).isin([1, 4, 7, 10])]

# %%
df_dk_controls.date.min()
# Out:
# Timestamp('2007-07-01 00:00:00')

# %% [markdown]
# #### Merge data

# %%
df_DK = df_dk_target.merge(df_dk_jobs, on = ['date', 'ID'])
df_DK.shape
# Out:
# (230, 15)

# %%
df_DK = df_DK.merge(df_dk_controls, on = ['date', 'ID'])
df_DK.shape
# Out:
# (230, 19)

# %%
df_DK.date.min()
# Out:
# Timestamp('2008-01-01 00:00:00')

# %%
df_DK[df_DK['jobs'].notnull()]
# Out:
#           date  target_actual       ID  target_lag      jobs  \
# 1   2008-04-01           4.13  Capital        3.92  3.432511
# 2   2008-07-01           3.72  Capital        4.13  2.837729
# 3   2008-10-01           3.88  Capital        3.72  2.253597
# 4   2009-01-01           6.18  Capital        3.88  1.941019
# 5   2009-04-01           6.56  Capital        6.18  1.766508
# ..         ...            ...      ...         ...       ...
# 225 2018-04-01           5.66  Zealand        5.85  1.936132
# 226 2018-07-01           4.64  Zealand        5.66  1.658612
# 227 2018-10-01           5.44  Zealand        4.64  1.706443
# 228 2019-01-01           5.64  Zealand        5.44  1.949482
# 229 2019-04-01           4.76  Zealand        5.64  1.893846
#
#      sector_information_technology  sector_engineering_technology  \
# 1                         0.269507                       0.229372
# 2                         0.236353                       0.195413
# 3                         0.179017                       0.171703
# 4                         0.129733                       0.139442
# 5                         0.097506                       0.103444
# ..                             ...                            ...
# 225                       0.058779                       0.134351
# 226                       0.064781                       0.124936
# 227                       0.067526                       0.125773
# 228                       0.073834                       0.131347
# 229                       0.057692                       0.125385
#
#      sector_management_staff  sector_trade_service  sector_industry_craft  \
# 1                   0.342377              0.502130               0.298991
# 2                   0.294151              0.424885               0.221101
# 3                   0.253118              0.277818               0.119424
# 4                   0.204126              0.239806               0.083374
# 5                   0.180998              0.239667               0.089430
# ..                       ...                   ...                    ...
# 225                 0.178117              0.269975               0.282697
# 226                 0.170694              0.223907               0.235219
# 227                 0.198454              0.226289               0.214948
# 228                 0.202073              0.263731               0.265803
# 229                 0.192564              0.270256               0.271795
#
#      sector_sales_communication  sector_teaching  sector_office_finance  \
# 1                      0.262332         0.404260               0.754933
# 2                      0.221674         0.356995               0.601147
# 3                      0.174460         0.297842               0.485731
# 4                      0.130947         0.264078               0.399879
# 5                      0.126841         0.273397               0.315321
# ..                          ...              ...                    ...
# 225                    0.124682         0.289059               0.210178
# 226                    0.123136         0.235219               0.184576
# 227                    0.134278         0.268814               0.195876
# 228                    0.148446         0.238601               0.230052
# 229                    0.124103         0.277949               0.201282
#
#      sector_social_health  sector_other      pop  mvu_lvu_share_pop  \
# 1                0.402130      0.372197  1645825          18.521046
# 2                0.338188      0.288073  1648990          19.020249
# 3                0.330096      0.235612  1650985          18.997265
# 4                0.357403      0.228398  1660042          18.893618
# 5                0.289311      0.249525  1662285          18.868124
# ..                    ...           ...      ...                ...
# 225              0.484478      0.270738   835024          13.340814
# 226              0.418509      0.211568   835107          13.596821
# 227              0.430412      0.216753   836379          13.576142
# 228              0.516321      0.279016   836694          13.571031
# 229              0.454359      0.289231   836738          13.570317
#
#      labour_force_share  w_ave_urban_index
# 1             53.468625          97.179641
# 2             54.093718          97.218878
# 3             52.816955          97.216177
# 4             50.239693          97.229164
# 5             49.570320          97.233018
# ..                  ...                ...
# 225           47.783058          81.336569
# 226           47.059838          81.493495
# 227           46.510015          81.496870
# 228           46.372987          81.508824
# 229           46.131525          81.516754
#
# [225 rows x 19 columns]

# %%
df_DK['country'] = 'DK'

# %%
df_DK.head()
# Out:
#         date  target_actual       ID  target_lag      jobs  \
# 0 2008-01-01           3.92  Capital         NaN       NaN
# 1 2008-04-01           4.13  Capital        3.92  3.432511
# 2 2008-07-01           3.72  Capital        4.13  2.837729
# 3 2008-10-01           3.88  Capital        3.72  2.253597
# 4 2009-01-01           6.18  Capital        3.88  1.941019
#
#    sector_information_technology  sector_engineering_technology  \
# 0                            NaN                            NaN
# 1                       0.269507                       0.229372
# 2                       0.236353                       0.195413
# 3                       0.179017                       0.171703
# 4                       0.129733                       0.139442
#
#    sector_management_staff  sector_trade_service  sector_industry_craft  \
# 0                      NaN                   NaN                    NaN
# 1                 0.342377              0.502130               0.298991
# 2                 0.294151              0.424885               0.221101
# 3                 0.253118              0.277818               0.119424
# 4                 0.204126              0.239806               0.083374
#
#    sector_sales_communication  sector_teaching  sector_office_finance  \
# 0                         NaN              NaN                    NaN
# 1                    0.262332         0.404260               0.754933
# 2                    0.221674         0.356995               0.601147
# 3                    0.174460         0.297842               0.485731
# 4                    0.130947         0.264078               0.399879
#
#    sector_social_health  sector_other      pop  mvu_lvu_share_pop  \
# 0                   NaN           NaN  1644835          18.532193
# 1              0.402130      0.372197  1645825          18.521046
# 2              0.338188      0.288073  1648990          19.020249
# 3              0.330096      0.235612  1650985          18.997265
# 4              0.357403      0.228398  1660042          18.893618
#
#    labour_force_share  w_ave_urban_index country
# 0           54.716735          97.177557      DK
# 1           53.468625          97.179641      DK
# 2           54.093718          97.218878      DK
# 3           52.816955          97.216177      DK
# 4           50.239693          97.229164      DK

# %%
df_DK.date.max()
# Out:
# Timestamp('2019-04-01 00:00:00')

# %%
df_DK.date.min()
# Out:
# Timestamp('2008-01-01 00:00:00')

# %% [markdown]
# #### Save the data

# %%
df_DK.to_csv('data/DK_SE_NO/df_dk.csv')

# %% [markdown]
# ## SE

# %% [markdown]
# #### Target data

# %%
df_se_target = pd.read_csv(r'data/target/df_SE_target.csv', parse_dates = ['date'])

# %%
df_se_target.date.min()
# Out:
# Timestamp('2005-04-01 00:00:00')

# %%
df_se_target.date.max()
# Out:
# Timestamp('2019-04-01 00:00:00')

# %% [markdown]
# Create target lag

# %%
df_se_target['target_lag'] = df_se_target.target_actual.shift(1)

# %% [markdown]
# #### Job posts

# %%
df_se_jobs = pd.read_csv(r'data/job_posts/df_SE_jobposts_quarterly_final.csv', parse_dates = ['date'])

# %%
df_se_jobs = df_se_jobs.drop(['labour_force'], axis = 1)

# %% [markdown]
# Merge on labour force

# %%
df_se_labour = pd.read_csv(r'data/job_posts/df_SE_labour_force.csv', parse_dates = ['date'])

# %%
df_se_jobs = df_se_jobs.merge(df_se_labour, on = ['date', 'ID'])

# %%
df_se_jobs['labour_force'] = df_se_jobs.groupby('ID').labour_force.shift(1)

# %% [markdown]
# Create job rate

# %%
jobs_list = ['jobs', 'sector_information_technology', 'sector_engineering_technology','sector_management_staff', 'sector_trade_service',
       'sector_industry_craft', 'sector_sales_communication',
       'sector_teaching', 'sector_office_finance', 'sector_social_health',
       'sector_other']

# %%
for col in jobs_list:
    df_se_jobs[col] = (df_se_jobs[col] / df_se_jobs['labour_force'])*100

# %%
df_se_jobs = df_se_jobs.drop(['labour_force'], axis = 1)

# %% [markdown]
# #### Google

# %% [markdown]
# #### Regional

# %%
df_SE_controls = pd.read_csv('data/other/df_SE_controls.csv', parse_dates = ['date'])

# %%
df_SE_controls = df_SE_controls[['reg_nr','ID','date','pop', 'labour_force_share','mvu_lvu_share','urban_share']]

# %%
df_SE_controls = df_SE_controls.replace('Västra Götaland', 'Västra Götalands')

# %% [markdown]
# Shift controls

# %%
df_SE_controls['pop'] = df_SE_controls.groupby('ID').pop.shift(5)
df_SE_controls['labour_force_share'] = df_SE_controls.groupby('ID').labour_force_share.shift(1)
df_SE_controls['mvu_lvu_share'] = df_SE_controls.groupby('ID').mvu_lvu_share.shift(6)
df_SE_controls['urban_share'] = df_SE_controls.groupby('ID').urban_share.shift(7)

# %% [markdown]
# #### Merge data

# %%
df_SE = df_se_target.merge(df_se_jobs, on = ['date', 'ID'])

# %%
df_SE = df_SE.merge(df_SE_controls, on = ['date', 'ID'], how = 'left')

# %%
df_SE['country'] = 'SE'

# %%
df_SE = df_SE[df_SE.date >= '2007-01-01']

# %%
df_SE.date.min()
# Out:
# Timestamp('2007-01-01 00:00:00')

# %%
df_SE.date.max()
# Out:
# Timestamp('2019-04-01 00:00:00')

# %%
df_SE.shape
# Out:
# (1050, 21)

# %% [markdown]
# #### Save the data

# %% [markdown]
# ## NO

# %%
df_no_target = pd.read_csv(r'data/target/df_NO_target.csv',  parse_dates = ['date'])

# %% [markdown]
# #### Target data

# %%
df_no_target.date.min()
# Out:
# Timestamp('1996-01-01 00:00:00')

# %%
df_no_target.date.max()
# Out:
# Timestamp('2019-04-01 00:00:00')

# %% [markdown]
# Create target lag

# %%
df_no_target['target_lag'] = df_no_target.groupby('ID').target_actual.shift(1)

# %% [markdown]
# #### Job posts

# %%
df_no_jobs = pd.read_csv(r'data/job_posts/df_NO_jobposts_quarterly_final.csv', parse_dates = ['date'])

# %%
df_no_jobs = df_no_jobs.drop(['labour_force'], axis = 1)

# %% [markdown]
# Correct Nord- Sør trøndelag

# %%
test = df_no_jobs[df_no_jobs['ID'].str.startswith('Nord-Trøndelag')]
#test = test.reset_index()

test2 = df_no_jobs[df_no_jobs['ID'].str.startswith('Sør-Trøndelag')]
#test2 = test2.reset_index()

# %%
temp = pd.concat([test,test2])
temp = temp.groupby('date').sum()
temp['ID'] ='Trøndelag'

# %%
temp = temp.reset_index()

# %% [markdown]
# Correct labour force for those two regions

# %%
df = pd.read_csv("data/other/df_NO_labour_force.csv",  parse_dates = ['date'])
df = df[['date','labour_force', 'ID']]

# %%
test = df[df['ID'].str.startswith('Nord-Trøndelag')]
test = test.reset_index()

test2 = df[df['ID'].str.startswith('Sør-Trøndelag')]
test2 = test2.reset_index()

test3 = df[df['ID'].str.startswith('Trøndelag')]
test3 = test3.reset_index()

# %%
temp = pd.concat([test,test2, test3])
temp = temp.groupby('date').sum()
temp['ID'] ='Trøndelag'

# %%
temp = temp.reset_index()

# %%
temp = temp[['date', 'labour_force', 'ID']]

# %%
df= df[~df.ID.isin(['Nord-Trøndelag', 'Sør-Trøndelag', 'Trøndelag'])]

df = pd.concat([df, temp])
df['labour_force'] = df['labour_force']*1000

# %%
df_no_jobs = df_no_jobs.merge(df, on = ['date', 'ID'])

# %%
df_no_jobs['labour_force'] =  df_no_jobs.groupby('ID').labour_force.shift(1)

# %% [markdown]
# Create job rate

# %%
jobs_list = ['jobs', 'sector_information_technology', 'sector_engineering_technology','sector_management_staff', 'sector_trade_service',
       'sector_industry_craft', 'sector_sales_communication',
       'sector_teaching', 'sector_office_finance', 'sector_social_health',
       'sector_other']

# %%
for col in jobs_list:
    df_no_jobs[col] = (df_no_jobs[col] / df_no_jobs['labour_force'])*100

# %%
df_no_jobs = df_no_jobs.drop(['labour_force'], axis = 1)

# %% [markdown]
# #### Google

# %% [markdown]
# #### Regional

# %%
df_NO_controls = pd.read_csv('data/other/df_NO_controls.csv', parse_dates = ['date'])

# %%
df_NO_controls.tail()
# Out:
#              ID       date     pop  reg_nr  labour_force_share  mvu_lvu_share  \
# 1219  Trøndelag 2018-10-01  458744      50                70.0           33.7
# 1220  Trøndelag 2019-01-01  464060      50                71.0            NaN
# 1221  Trøndelag 2019-04-01  464060      50                70.0            NaN
# 1222  Trøndelag 2019-07-01  464060      50                 NaN            NaN
# 1223  Trøndelag 2019-10-01  464060      50                 NaN            NaN
#
#       urban_share
# 1219    74.662993
# 1220          NaN
# 1221          NaN
# 1222          NaN
# 1223          NaN

# %%
df_NO_controls = df_NO_controls.replace('Finnmark - Finnmárku', 'Finnmark')
df_NO_controls = df_NO_controls.replace('Troms - Romsa', 'Troms')

# %% [markdown]
# Shift controls

# %%
df_NO_controls['pop'] = df_NO_controls.groupby('ID').pop.shift(1)
df_NO_controls['labour_force_share'] = df_NO_controls.groupby('ID').labour_force_share.shift(1)
df_NO_controls['mvu_lvu_share'] = df_NO_controls.groupby('ID').mvu_lvu_share.shift(6)
df_NO_controls['urban_share'] = df_NO_controls.groupby('ID').urban_share.shift(4)

# %%
df_NO_controls.tail()
# Out:
#              ID       date       pop  reg_nr  labour_force_share  \
# 1219  Trøndelag 2018-10-01  458744.0      50                70.0
# 1220  Trøndelag 2019-01-01  458744.0      50                70.0
# 1221  Trøndelag 2019-04-01  464060.0      50                71.0
# 1222  Trøndelag 2019-07-01  464060.0      50                70.0
# 1223  Trøndelag 2019-10-01  464060.0      50                 NaN
#
#       mvu_lvu_share  urban_share
# 1219          31.15    74.361851
# 1220          31.15    74.662993
# 1221          31.15    74.662993
# 1222          33.70    74.662993
# 1223          33.70    74.662993

# %% [markdown]
# #### Merge data

# %%
df_NO = df_no_target.merge(df_no_jobs, on = ['date', 'ID'])

# %%
df_NO = df_NO.merge(df_NO_controls, on = ['date', 'ID'], how = 'left')

# %%
df_NO['country'] = 'NO'

# %%
df_NO = df_NO[df_NO.date >= '2007-01-01']

# %%
df_NO.date.min()
# Out:
# Timestamp('2007-01-01 00:00:00')

# %%
df_NO.date.max()
# Out:
# Timestamp('2019-04-01 00:00:00')

# %% [markdown]
# #### Save the data

# %% [markdown]
# ## Concat the files

# %%
df_DK = df_DK.rename(columns = {'pop' : 'population', 'mvu_lvu_share_pop' : 'high_edu_share',
       'w_ave_urban_index' : 'urban_share'})

# %%
df_DK = df_DK[['date', 'target_actual', 'ID', 'target_lag', 'jobs',
       'sector_information_technology', 'sector_engineering_technology',
       'sector_management_staff', 'sector_trade_service',
       'sector_industry_craft', 'sector_sales_communication',
       'sector_teaching', 'sector_office_finance', 'sector_social_health',
       'sector_other', 'population', 'high_edu_share', 'labour_force_share',
       'urban_share', 'country']]

# %%
df_DK.columns
# Out:
# Index(['date', 'target_actual', 'ID', 'target_lag', 'jobs',
#        'sector_information_technology', 'sector_engineering_technology',
#        'sector_management_staff', 'sector_trade_service',
#        'sector_industry_craft', 'sector_sales_communication',
#        'sector_teaching', 'sector_office_finance', 'sector_social_health',
#        'sector_other', 'population', 'high_edu_share', 'labour_force_share',
#        'urban_share', 'country'],
#       dtype='object')

# %%
df_SE = df_SE.rename(columns = {'pop' : 'population', 'mvu_lvu_share' : 'high_edu_share'})

# %%
df_SE = df_SE[['date', 'target_actual', 'ID', 'target_lag', 'jobs',
       'sector_information_technology', 'sector_engineering_technology',
       'sector_management_staff', 'sector_trade_service',
       'sector_industry_craft', 'sector_sales_communication',
       'sector_teaching', 'sector_office_finance', 'sector_social_health',
       'sector_other', 'population', 'high_edu_share', 'labour_force_share',
       'urban_share', 'country']]

# %%
df_SE.columns
# Out:
# Index(['date', 'target_actual', 'ID', 'target_lag', 'jobs',
#        'sector_information_technology', 'sector_engineering_technology',
#        'sector_management_staff', 'sector_trade_service',
#        'sector_industry_craft', 'sector_sales_communication',
#        'sector_teaching', 'sector_office_finance', 'sector_social_health',
#        'sector_other', 'population', 'high_edu_share', 'labour_force_share',
#        'urban_share', 'country'],
#       dtype='object')

# %%
df_NO = df_NO.rename(columns = {'pop' : 'population', 'mvu_lvu_share' : 'high_edu_share',
       'w_ave_urban_index' : 'urban_share'})

# %%
df_NO = df_NO[['date', 'target_actual', 'ID', 'target_lag', 'jobs',
       'sector_information_technology', 'sector_engineering_technology',
       'sector_management_staff', 'sector_trade_service',
       'sector_industry_craft', 'sector_sales_communication',
       'sector_teaching', 'sector_office_finance', 'sector_social_health',
       'sector_other', 'population', 'high_edu_share', 'labour_force_share',
       'urban_share', 'country']]

# %%
df_NO.columns
# Out:
# Index(['date', 'target_actual', 'ID', 'target_lag', 'jobs',
#        'sector_information_technology', 'sector_engineering_technology',
#        'sector_management_staff', 'sector_trade_service',
#        'sector_industry_craft', 'sector_sales_communication',
#        'sector_teaching', 'sector_office_finance', 'sector_social_health',
#        'sector_other', 'population', 'high_edu_share', 'labour_force_share',
#        'urban_share', 'country'],
#       dtype='object')

# %%
df_descriptive = pd.concat([df_DK, df_SE, df_NO])

# %%
df_descriptive
# Out:
#            date  target_actual        ID  target_lag      jobs  \
# 0    2008-01-01           3.92   Capital         NaN       NaN
# 1    2008-04-01           4.13   Capital        3.92  3.432511
# 2    2008-07-01           3.72   Capital        4.13  2.837729
# 3    2008-10-01           3.88   Capital        3.72  2.253597
# 4    2009-01-01           6.18   Capital        3.88  1.941019
# ...         ...            ...       ...         ...       ...
# 1049 2018-04-01           5.00  Finnmark        5.13  2.497436
# 1050 2018-07-01           2.56  Finnmark        5.00  1.960000
# 1051 2018-10-01           5.13  Finnmark        2.56  2.338462
# 1052 2019-01-01           7.50  Finnmark        5.13  2.446154
# 1053 2019-04-01           5.13  Finnmark        7.50  0.282500
#
#       sector_information_technology  sector_engineering_technology  \
# 0                               NaN                            NaN
# 1                          0.269507                       0.229372
# 2                          0.236353                       0.195413
# 3                          0.179017                       0.171703
# 4                          0.129733                       0.139442
# ...                             ...                            ...
# 1049                       0.046154                       0.097436
# 1050                       0.067500                       0.102500
# 1051                       0.053846                       0.158974
# 1052                       0.087179                       0.138462
# 1053                       0.137500                       0.142500
#
#       sector_management_staff  sector_trade_service  sector_industry_craft  \
# 0                         NaN                   NaN                    NaN
# 1                    0.342377              0.502130               0.298991
# 2                    0.294151              0.424885               0.221101
# 3                    0.253118              0.277818               0.119424
# 4                    0.204126              0.239806               0.083374
# ...                       ...                   ...                    ...
# 1049                 0.248718              0.315385               0.187179
# 1050                 0.170000              0.237500               0.217500
# 1051                 0.320513              0.233333               0.238462
# 1052                 0.228205              0.279487               0.212821
# 1053                 0.285000              0.292500               0.175000
#
#       sector_sales_communication  sector_teaching  sector_office_finance  \
# 0                            NaN              NaN                    NaN
# 1                       0.262332         0.404260               0.754933
# 2                       0.221674         0.356995               0.601147
# 3                       0.174460         0.297842               0.485731
# 4                       0.130947         0.264078               0.399879
# ...                          ...              ...                    ...
# 1049                    0.182051         0.400000               0.151282
# 1050                    0.122500         0.167500               0.165000
# 1051                    0.171795         0.256410               0.187179
# 1052                    0.143590         0.335897               0.187179
# 1053                    0.165000         0.347500               0.165000
#
#       sector_social_health  sector_other  population  high_edu_share  \
# 0                      NaN           NaN   1644835.0       18.532193
# 1                 0.402130      0.372197   1645825.0       18.521046
# 2                 0.338188      0.288073   1648990.0       19.020249
# 3                 0.330096      0.235612   1650985.0       18.997265
# 4                 0.357403      0.228398   1660042.0       18.893618
# ...                    ...           ...         ...             ...
# 1049              0.728205      0.441026     76167.0       27.000000
# 1050              0.602500      0.385000     76167.0       27.400000
# 1051              0.666667      0.369231     76167.0       27.400000
# 1052              0.651282      0.469231     76167.0       27.400000
# 1053              0.665000      0.465000     75865.0       27.400000
#
#       labour_force_share  urban_share country
# 0              54.716735    97.177557      DK
# 1              53.468625    97.179641      DK
# 2              54.093718    97.218878      DK
# 3              52.816955    97.216177      DK
# 4              50.239693    97.229164      DK
# ...                  ...          ...     ...
# 1049           68.000000    77.366742      NO
# 1050           69.000000    77.366742      NO
# 1051           69.000000    77.366742      NO
# 1052           69.000000    77.721323      NO
# 1053           70.000000    77.721323      NO
#
# [1978 rows x 20 columns]

# %% [markdown]
# Secure that all are the same period

# %%
df_descriptive = df_descriptive[df_descriptive.date >= df_DK.date.min()]
df_descriptive = df_descriptive[df_descriptive.date <= df_DK.date.max()]

# %% [markdown]
# Check the data

# %%
df_descriptive.ID.value_counts()
# Out:
# Akershus            46
# Aust-Agder          46
# Gävleborg           46
# Oppland             46
# Hordaland           46
# Møre og Romsdal     46
# Southern Denmark    46
# Troms               46
# Oslo                46
# Kronoberg           46
# Värmland            46
# Gotland             46
# Västernorrland      46
# Buskerud            46
# Jämtland            46
# Sogn og Fjordane    46
# Dalarna             46
# Södermanland        46
# Jönköping           46
# Zealand             46
# Kalmar              46
# Blekinge            46
# Telemark            46
# Nordland            46
# Rogaland            46
# Stockholm           46
# Västra Götalands    46
# Uppsala             46
# Norrbotten          46
# Skåne               46
# North Denmark       46
# Halland             46
# Hedmark             46
# Västmanland         46
# Østfold             46
# Örebro              46
# Västerbotten        46
# Östergötland        46
# Central Denmark     46
# Vestfold            46
# Vest-Agder          46
# Capital             46
# Finnmark            46
# Name: ID, dtype: int64

# %%
df_descriptive.country.value_counts()
# Out:
# SE    966
# NO    782
# DK    230
# Name: country, dtype: int64

# %%
df_descriptive.isnull().sum()
# Out:
# date                             0
# target_actual                    0
# ID                               0
# target_lag                       5
# jobs                             5
# sector_information_technology    5
# sector_engineering_technology    5
# sector_management_staff          5
# sector_trade_service             5
# sector_industry_craft            5
# sector_sales_communication       5
# sector_teaching                  5
# sector_office_finance            5
# sector_social_health             5
# sector_other                     5
# population                       0
# high_edu_share                   0
# labour_force_share               0
# urban_share                      0
# country                          0
# dtype: int64

# %%
temp = df_descriptive[df_descriptive.date.dt.year == 2010]
temp[temp.urban_share.isnull()]
# Out:
# Empty DataFrame
# Columns: [date, target_actual, ID, target_lag, jobs, sector_information_technology, sector_engineering_technology, sector_management_staff, sector_trade_service, sector_industry_craft, sector_sales_communication, sector_teaching, sector_office_finance, sector_social_health, sector_other, population, high_edu_share, labour_force_share, urban_share, country]
# Index: []

# %%
df_descriptive.date.max()
# Out:
# Timestamp('2019-04-01 00:00:00')

# %%
df_descriptive.date.min()
# Out:
# Timestamp('2008-01-01 00:00:00')

# %% [markdown]
# Mean table

# %%
df_descriptive.groupby('country').mean()
# Out:
#          target_actual  target_lag      jobs  sector_information_technology  \
# country
# DK            6.513783    6.551067  1.790177                       0.100824
# NO            3.668120    3.638146  1.777810                       0.071445
# SE            7.527557    7.495859  1.630532                       0.125786
#
#          sector_engineering_technology  sector_management_staff  \
# country
# DK                            0.146816                 0.209666
# NO                            0.178991                 0.117238
# SE                            0.099581                 0.083549
#
#          sector_trade_service  sector_industry_craft  \
# country
# DK                   0.244152               0.192992
# NO                   0.215437               0.194978
# SE                   0.235024               0.174969
#
#          sector_sales_communication  sector_teaching  sector_office_finance  \
# country
# DK                         0.167656         0.209310               0.263178
# NO                         0.279041         0.263173               0.142080
# SE                         0.296840         0.298750               0.226633
#
#          sector_social_health  sector_other    population  high_edu_share  \
# country
# DK                   0.304478      0.258605  1.125711e+06       15.083701
# NO                   0.521633      0.238751  2.704953e+05       27.150128
# SE                   0.351321      0.138599  4.572620e+05       21.985772
#
#          labour_force_share  urban_share
# country
# DK                49.806724    85.299181
# NO                70.127877    75.603188
# SE                72.430331    80.112908

# %% [markdown]
# ## GT

# %%
dfTrends = pd.read_csv('data/gt/dfTrends.csv', index_col=0, sep = ';', parse_dates=['date'])

# %%
dfTrends.drop(['geo', 'trends', 'C_ID'], axis=1, inplace=True)

# %%
df_descriptive.shape
# Out:
# (1978, 20)

# %%
df_descriptive = pd.merge(df_descriptive, dfTrends, how = 'left', left_on=['ID', 'date'], right_on=['ID', 'date'])

# %%
df_descriptive.shape
# Out:
# (1978, 58)

# %% [markdown]
# ### Reindexing GT

# %%
#Reindexing trends
df_descriptive = df_descriptive.apply(lambda col: reindex(col) if col.name in GT_dict() else col).copy()

# %%
df_descriptive.columns
# Out:
# Index(['date', 'target_actual', 'ID', 'target_lag', 'jobs',
#        'sector_information_technology', 'sector_engineering_technology',
#        'sector_management_staff', 'sector_trade_service',
#        'sector_industry_craft', 'sector_sales_communication',
#        'sector_teaching', 'sector_office_finance', 'sector_social_health',
#        'sector_other', 'population', 'high_edu_share', 'labour_force_share',
#        'urban_share', 'country', 'GT_DK_0', 'GT_DK_2', 'GT_DK_3', 'GT_DK_4',
#        'GT_DK_5', 'GT_DK_6', 'GT_DK_7', 'GT_DK_8', 'GT_DK_9', 'GT_DK_10',
#        'GT_DK_11', 'GT_DK_12', 'GT_DK_13', 'GT_DK_14', 'GT_DK_15', 'GT_DK_16',
#        'GT_DK_17', 'GT_DK_18', 'GT_DK_19', 'GT_DK_20', 'GT_DK_21', 'GT_NO_0',
#        'GT_NO_1', 'GT_NO_2', 'GT_NO_6', 'GT_NO_7', 'GT_NO_8', 'GT_NO_10',
#        'GT_NO_11', 'GT_SE_0', 'GT_SE_1', 'GT_SE_2', 'GT_SE_6', 'GT_SE_7',
#        'GT_SE_8', 'GT_SE_9', 'GT_SE_10', 'GT_SE_11'],
#       dtype='object')

# %%
df_descriptive.groupby(['country', 'ID'])[['GT_DK_0', 'GT_DK_2', 'GT_DK_3', 'GT_DK_4',
       'GT_DK_5', 'GT_DK_6', 'GT_DK_7', 'GT_DK_8', 'GT_DK_9', 'GT_DK_10',
       'GT_DK_11', 'GT_DK_12', 'GT_DK_13', 'GT_DK_14', 'GT_DK_15', 'GT_DK_16',
       'GT_DK_17', 'GT_DK_18', 'GT_DK_19', 'GT_DK_20', 'GT_DK_21', 'GT_NO_0',
       'GT_NO_1', 'GT_NO_2', 'GT_NO_6', 'GT_NO_7', 'GT_NO_8', 'GT_NO_10',
       'GT_NO_11', 'GT_SE_0', 'GT_SE_1', 'GT_SE_2', 'GT_SE_6', 'GT_SE_7',
       'GT_SE_8', 'GT_SE_9', 'GT_SE_10', 'GT_SE_11']].mean()
# Out:
#                             GT_DK_0    GT_DK_2    GT_DK_3    GT_DK_4  \
# country ID
# DK      Capital           58.280435  77.707174  70.633261  68.540870
#         Central Denmark   52.279783  79.418261  61.061957  71.597174
#         North Denmark     44.593913  66.556522  62.797391  60.602174
#         Southern Denmark  53.249130  81.500435  65.025652  72.006522
#         Zealand           37.876739  76.360217  59.794565  48.078478
# NO      Akershus           0.000000   0.000000   0.000000   0.000000
#         Aust-Agder         0.000000   0.000000   0.000000   0.000000
#         Buskerud           0.000000   0.000000   0.000000   0.000000
#         Finnmark           0.000000   0.000000   0.000000   0.000000
#         Hedmark            0.000000   0.000000   0.000000   0.000000
#         Hordaland          0.000000   0.000000   0.000000   0.000000
#         Møre og Romsdal    0.000000   0.000000   0.000000   0.000000
#         Nordland           0.000000   0.000000   0.000000   0.000000
#         Oppland            0.000000   0.000000   0.000000   0.000000
#         Oslo               0.000000   0.000000   0.000000   0.000000
#         Rogaland           0.000000   0.000000   0.000000   0.000000
#         Sogn og Fjordane   0.000000   0.000000   0.000000   0.000000
#         Telemark           0.000000   0.000000   0.000000   0.000000
#         Troms              0.000000   0.000000   0.000000   0.000000
#         Vest-Agder         0.000000   0.000000   0.000000   0.000000
#         Vestfold           0.000000   0.000000   0.000000   0.000000
#         Østfold            0.000000   0.000000   0.000000   0.000000
# SE      Blekinge           0.000000   0.000000   0.000000   0.000000
#         Dalarna            0.000000   0.000000   0.000000   0.000000
#         Gotland            0.000000   0.000000   0.000000   0.000000
#         Gävleborg          0.000000   0.000000   0.000000   0.000000
#         Halland            0.000000   0.000000   0.000000   0.000000
#         Jämtland           0.000000   0.000000   0.000000   0.000000
#         Jönköping          0.000000   0.000000   0.000000   0.000000
#         Kalmar             0.000000   0.000000   0.000000   0.000000
#         Kronoberg          0.000000   0.000000   0.000000   0.000000
#         Norrbotten         0.000000   0.000000   0.000000   0.000000
#         Skåne              0.000000   0.000000   0.000000   0.000000
#         Stockholm          0.000000   0.000000   0.000000   0.000000
#         Södermanland       0.000000   0.000000   0.000000   0.000000
#         Uppsala            0.000000   0.000000   0.000000   0.000000
#         Värmland           0.000000   0.000000   0.000000   0.000000
#         Västerbotten       0.000000   0.000000   0.000000   0.000000
#         Västernorrland     0.000000   0.000000   0.000000   0.000000
#         Västmanland        0.000000   0.000000   0.000000   0.000000
#         Västra Götalands   0.000000   0.000000   0.000000   0.000000
#         Örebro             0.000000   0.000000   0.000000   0.000000
#         Östergötland       0.000000   0.000000   0.000000   0.000000
#
#                             GT_DK_5    GT_DK_6    GT_DK_7    GT_DK_8  \
# country ID
# DK      Capital           79.111739  67.275217  60.147609  44.618913
#         Central Denmark   74.055217  38.767826  68.359348  35.289565
#         North Denmark     38.261087  12.565217  68.314783  31.912826
#         Southern Denmark  66.757609  23.737391  52.024565  40.355000
#         Zealand           41.795652  18.361739  53.595217  43.563043
# NO      Akershus           0.000000   0.000000   0.000000   0.000000
#         Aust-Agder         0.000000   0.000000   0.000000   0.000000
#         Buskerud           0.000000   0.000000   0.000000   0.000000
#         Finnmark           0.000000   0.000000   0.000000   0.000000
#         Hedmark            0.000000   0.000000   0.000000   0.000000
#         Hordaland          0.000000   0.000000   0.000000   0.000000
#         Møre og Romsdal    0.000000   0.000000   0.000000   0.000000
#         Nordland           0.000000   0.000000   0.000000   0.000000
#         Oppland            0.000000   0.000000   0.000000   0.000000
#         Oslo               0.000000   0.000000   0.000000   0.000000
#         Rogaland           0.000000   0.000000   0.000000   0.000000
#         Sogn og Fjordane   0.000000   0.000000   0.000000   0.000000
#         Telemark           0.000000   0.000000   0.000000   0.000000
#         Troms              0.000000   0.000000   0.000000   0.000000
#         Vest-Agder         0.000000   0.000000   0.000000   0.000000
#         Vestfold           0.000000   0.000000   0.000000   0.000000
#         Østfold            0.000000   0.000000   0.000000   0.000000
# SE      Blekinge           0.000000   0.000000   0.000000   0.000000
#         Dalarna            0.000000   0.000000   0.000000   0.000000
#         Gotland            0.000000   0.000000   0.000000   0.000000
#         Gävleborg          0.000000   0.000000   0.000000   0.000000
#         Halland            0.000000   0.000000   0.000000   0.000000
#         Jämtland           0.000000   0.000000   0.000000   0.000000
#         Jönköping          0.000000   0.000000   0.000000   0.000000
#         Kalmar             0.000000   0.000000   0.000000   0.000000
#         Kronoberg          0.000000   0.000000   0.000000   0.000000
#         Norrbotten         0.000000   0.000000   0.000000   0.000000
#         Skåne              0.000000   0.000000   0.000000   0.000000
#         Stockholm          0.000000   0.000000   0.000000   0.000000
#         Södermanland       0.000000   0.000000   0.000000   0.000000
#         Uppsala            0.000000   0.000000   0.000000   0.000000
#         Värmland           0.000000   0.000000   0.000000   0.000000
#         Västerbotten       0.000000   0.000000   0.000000   0.000000
#         Västernorrland     0.000000   0.000000   0.000000   0.000000
#         Västmanland        0.000000   0.000000   0.000000   0.000000
#         Västra Götalands   0.000000   0.000000   0.000000   0.000000
#         Örebro             0.000000   0.000000   0.000000   0.000000
#         Östergötland       0.000000   0.000000   0.000000   0.000000
#
#                             GT_DK_9   GT_DK_10  ...   GT_NO_11    GT_SE_0  \
# country ID                                      ...
# DK      Capital           53.470217  78.751522  ...   0.000000   0.000000
#         Central Denmark   57.038043  73.349348  ...   0.000000   0.000000
#         North Denmark     54.112174  47.735652  ...   0.000000   0.000000
#         Southern Denmark  52.917609  64.106522  ...   0.000000   0.000000
#         Zealand           52.763261  58.467391  ...   0.000000   0.000000
# NO      Akershus           0.000000   0.000000  ...  24.803043   0.000000
#         Aust-Agder         0.000000   0.000000  ...   6.173913   0.000000
#         Buskerud           0.000000   0.000000  ...   5.935000   0.000000
#         Finnmark           0.000000   0.000000  ...   4.843696   0.000000
#         Hedmark            0.000000   0.000000  ...   3.393478   0.000000
#         Hordaland          0.000000   0.000000  ...  22.490870   0.000000
#         Møre og Romsdal    0.000000   0.000000  ...   7.273696   0.000000
#         Nordland           0.000000   0.000000  ...  10.758913   0.000000
#         Oppland            0.000000   0.000000  ...   6.054348   0.000000
#         Oslo               0.000000   0.000000  ...  75.728913   0.000000
#         Rogaland           0.000000   0.000000  ...  10.548043   0.000000
#         Sogn og Fjordane   0.000000   0.000000  ...   7.549783   0.000000
#         Telemark           0.000000   0.000000  ...  11.989348   0.000000
#         Troms              0.000000   0.000000  ...  10.970217   0.000000
#         Vest-Agder         0.000000   0.000000  ...  10.860435   0.000000
#         Vestfold           0.000000   0.000000  ...  10.584565   0.000000
#         Østfold            0.000000   0.000000  ...  16.153261   0.000000
# SE      Blekinge           0.000000   0.000000  ...   0.000000  36.366957
#         Dalarna            0.000000   0.000000  ...   0.000000  59.726739
#         Gotland            0.000000   0.000000  ...   0.000000  20.401739
#         Gävleborg          0.000000   0.000000  ...   0.000000  54.864348
#         Halland            0.000000   0.000000  ...   0.000000  56.073913
#         Jämtland           0.000000   0.000000  ...   0.000000  34.087609
#         Jönköping          0.000000   0.000000  ...   0.000000  51.987174
#         Kalmar             0.000000   0.000000  ...   0.000000  53.691304
#         Kronoberg          0.000000   0.000000  ...   0.000000  50.830652
#         Norrbotten         0.000000   0.000000  ...   0.000000  50.605217
#         Skåne              0.000000   0.000000  ...   0.000000  60.952174
#         Stockholm          0.000000   0.000000  ...   0.000000  58.441957
#         Södermanland       0.000000   0.000000  ...   0.000000  54.713043
#         Uppsala            0.000000   0.000000  ...   0.000000  56.020870
#         Värmland           0.000000   0.000000  ...   0.000000  60.197609
#         Västerbotten       0.000000   0.000000  ...   0.000000  55.917174
#         Västernorrland     0.000000   0.000000  ...   0.000000  47.684348
#         Västmanland        0.000000   0.000000  ...   0.000000  56.386522
#         Västra Götalands   0.000000   0.000000  ...   0.000000  58.307391
#         Örebro             0.000000   0.000000  ...   0.000000  54.803478
#         Östergötland       0.000000   0.000000  ...   0.000000  53.795000
#
#                             GT_SE_1    GT_SE_2    GT_SE_6    GT_SE_7  \
# country ID
# DK      Capital            0.000000   0.000000   0.000000   0.000000
#         Central Denmark    0.000000   0.000000   0.000000   0.000000
#         North Denmark      0.000000   0.000000   0.000000   0.000000
#         Southern Denmark   0.000000   0.000000   0.000000   0.000000
#         Zealand            0.000000   0.000000   0.000000   0.000000
# NO      Akershus           0.000000   0.000000   0.000000   0.000000
#         Aust-Agder         0.000000   0.000000   0.000000   0.000000
#         Buskerud           0.000000   0.000000   0.000000   0.000000
#         Finnmark           0.000000   0.000000   0.000000   0.000000
#         Hedmark            0.000000   0.000000   0.000000   0.000000
#         Hordaland          0.000000   0.000000   0.000000   0.000000
#         Møre og Romsdal    0.000000   0.000000   0.000000   0.000000
#         Nordland           0.000000   0.000000   0.000000   0.000000
#         Oppland            0.000000   0.000000   0.000000   0.000000
#         Oslo               0.000000   0.000000   0.000000   0.000000
#         Rogaland           0.000000   0.000000   0.000000   0.000000
#         Sogn og Fjordane   0.000000   0.000000   0.000000   0.000000
#         Telemark           0.000000   0.000000   0.000000   0.000000
#         Troms              0.000000   0.000000   0.000000   0.000000
#         Vest-Agder         0.000000   0.000000   0.000000   0.000000
#         Vestfold           0.000000   0.000000   0.000000   0.000000
#         Østfold            0.000000   0.000000   0.000000   0.000000
# SE      Blekinge          42.903913  25.687174  12.583043  23.928261
#         Dalarna           56.459565  31.622174  17.184783  34.826304
#         Gotland           16.801087   7.404565   9.605870  15.463043
#         Gävleborg         68.920435  36.926522  11.379130  50.193478
#         Halland           44.068696  44.361087   8.588261  46.898913
#         Jämtland          32.655217  18.378261  10.663478  30.323261
#         Jönköping         69.401522  42.068478  16.403043  45.236304
#         Kalmar            52.803043  13.658913  22.865217  38.121957
#         Kronoberg         60.885652  31.488913  14.032609  50.029348
#         Norrbotten        66.692391  40.799130  15.814348  39.828043
#         Skåne             64.921957  48.263478  51.694348  49.124348
#         Stockholm         68.865870  47.454565  32.540652  45.815000
#         Södermanland      39.317174  27.941739  15.275870  26.458043
#         Uppsala           68.819783  45.712391  14.463043  43.485870
#         Värmland          60.885652  41.764348  17.968913  61.759783
#         Västerbotten      49.650652  38.358913  12.778478  44.924783
#         Västernorrland    70.830435  41.683696  35.566304  53.502174
#         Västmanland       72.220217  38.380870  34.008478  29.923261
#         Västra Götalands  68.602174  46.452826  39.727609  48.463913
#         Örebro            58.689130  46.305217  16.314130  46.646739
#         Östergötland      64.425435  38.151304  26.713696  44.517826
#
#                             GT_SE_8    GT_SE_9   GT_SE_10   GT_SE_11
# country ID
# DK      Capital            0.000000   0.000000   0.000000   0.000000
#         Central Denmark    0.000000   0.000000   0.000000   0.000000
#         North Denmark      0.000000   0.000000   0.000000   0.000000
#         Southern Denmark   0.000000   0.000000   0.000000   0.000000
#         Zealand            0.000000   0.000000   0.000000   0.000000
# NO      Akershus           0.000000   0.000000   0.000000   0.000000
#         Aust-Agder         0.000000   0.000000   0.000000   0.000000
#         Buskerud           0.000000   0.000000   0.000000   0.000000
#         Finnmark           0.000000   0.000000   0.000000   0.000000
#         Hedmark            0.000000   0.000000   0.000000   0.000000
#         Hordaland          0.000000   0.000000   0.000000   0.000000
#         Møre og Romsdal    0.000000   0.000000   0.000000   0.000000
#         Nordland           0.000000   0.000000   0.000000   0.000000
#         Oppland            0.000000   0.000000   0.000000   0.000000
#         Oslo               0.000000   0.000000   0.000000   0.000000
#         Rogaland           0.000000   0.000000   0.000000   0.000000
#         Sogn og Fjordane   0.000000   0.000000   0.000000   0.000000
#         Telemark           0.000000   0.000000   0.000000   0.000000
#         Troms              0.000000   0.000000   0.000000   0.000000
#         Vest-Agder         0.000000   0.000000   0.000000   0.000000
#         Vestfold           0.000000   0.000000   0.000000   0.000000
#         Østfold            0.000000   0.000000   0.000000   0.000000
# SE      Blekinge          23.489130  11.923261  14.819130  12.117826
#         Dalarna           25.855435  26.647174  17.877609  17.547174
#         Gotland           13.105000  16.883043   4.418261   3.338696
#         Gävleborg         47.425000  46.050000  27.120217  16.766739
#         Halland           36.601522  10.508696  26.042174  11.524783
#         Jämtland          31.352174  10.140435  18.566304  24.162609
#         Jönköping         40.401957  41.893913  32.821304  25.619565
#         Kalmar            18.578913   8.290652  14.802174  17.318261
#         Kronoberg         46.724130  22.579783  24.637609  16.829130
#         Norrbotten        33.356087  40.302174  28.366304  38.299565
#         Skåne             57.393261  40.788478  75.370435  51.820217
#         Stockholm         69.496957  59.750000  73.948696  66.829565
#         Södermanland      25.501304  11.444130  18.778478  15.570870
#         Uppsala           50.678261  46.248913  39.068043  41.220652
#         Värmland          26.387826  19.955435  19.741304  23.767826
#         Västerbotten      48.250870  39.682391  22.313043  28.677174
#         Västernorrland    53.592826  22.682609  28.455217  27.158261
#         Västmanland       26.387391  33.271304  27.342174  20.886522
#         Västra Götalands  72.146957  52.490217  74.637174  49.459565
#         Örebro            40.896304  29.668478  32.467174  16.891739
#         Östergötland      60.476304  50.457174  35.480652  48.179565
#
# [43 rows x 38 columns]

# %% [markdown]
# ## Exporting

# %%
df_descriptive.to_csv('data/DK_SE_NO/descriptive/df_descriptive.csv', index = False)
